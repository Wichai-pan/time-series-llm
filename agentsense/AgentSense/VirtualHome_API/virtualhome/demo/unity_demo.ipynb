# %% [markdown]
# # Demo VirtualHome

# %% [markdown]
# This is a demo of how to run VirtualHome UnitySimulator. The demo will walk though how to start an environment and visualize it, how to prepare it to perform activities and finally how to perform activities in them.
#
# <img src=https://raw.githubusercontent.com/xavierpuigf/virtualhome_unity/master/doc/assets/banner.gif />

# %% [markdown]
# # Setup
# The code below is only needed if you are running the demo in colab. It installs a package to stream content on Google Colab.
#
# **Note:** Make sure you have GPU enabled if you are running in colab.
#
# Select Runtime > Change runtime type > Hardware accelerator: GPU

# %%
import os
if 'google.colab' in str(get_ipython()):
    print('Running on CoLab')
    osname = "linux"
    # !pip install git+https://github.com/xavierpuigf/colabstreamer
    import colabstreamer
    colabstreamer.config_all()
    _xorg = colabstreamer.open_xorg()
    # Clone VirtualHome
    # !git clone https://github.com/xavierpuigf/virtualhome.git
    # %cd /content/virtualhome
    # !pip install -r requirements.txt
else:
    # %cd ..
    from sys import platform
    if platform == "darwin":
        osname = "macos"
    elif platform == "linux":
        osname = "linux"
    elif platform == "windows" or platform == 'win32':
        osname = "windows"
# Out:
# /home/yusuf/Desktop/megha/virtualhome-master/virtualhome
# /home/yusuf/miniforge3/envs/simulator_env/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# ## Download the simulator

# %%
if not os.path.isfile(f"{osname}_exec.zip"):
    ! wget http://virtual-home.org/release/simulator/v2.0/v2.3.0/linux_exec.zip
    ! unzip -q linux_exec.zip
# %cd demo
# Out:
# --2024-12-19 16:32:08--  http://virtual-home.org/release/simulator/v2.0/v2.3.0/linux_exec.zip
# Resolving virtual-home.org (virtual-home.org)... 128.30.100.223
# Connecting to virtual-home.org (virtual-home.org)|128.30.100.223|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 287682964 (274M) [application/zip]
# Saving to: ‘linux_exec.zip’
#
# linux_exec.zip        3%[                    ]  10.90M  3.81MB/s               ^C
# [linux_exec.zip]
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of linux_exec.zip or
#         linux_exec.zip.zip, and cannot find linux_exec.zip.ZIP, period.
# /home/yusuf/Desktop/megha/virtualhome-master/virtualhome/demo

# %% [markdown]
# # Imports

# %%
# %matplotlib notebook
import IPython.display
import glob
from utils_demo import *
from sys import platform
import sys
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm

import virtualhome
from unity_simulator.comm_unity import UnityCommunication
from unity_simulator import utils_viz

# %% [markdown]
# # Starting communication

# %% [markdown]
# The first step is to start a communication with the simulator. Make sure before you run this that you have downloaded the simulator, and placed it under the `simulation` folder. You will be interacting with the simulator with the communication `comm` created here. You can include the file name of the simulator or just call `UnityCommunication()` and manually open the executable.
#
# Select `manual` if you are opening the executable separately, and `auto` if the unity executable is still not open.
#
# Remember that if you are running this in a headless server, you will need to start a display in a separate terminal using:
#
# ```
# sudo python helper_scripts/startx $DISPLAY_NUM
# ```
#
# This is not needed if you are running a colab notebook.

# %%
mode = 'manual' # auto / manual
if mode == 'auto':
    if platform == 'darwin':
        exec_file = '../macos_exec*'
    else:
        exec_file = '../linux_exec*.x86_64'
    file_names = glob.glob(exec_file)
    if len(file_names) > 0:
        file_name = file_names[0]
        comm = UnityCommunication(file_name=file_name, port="8082", x_display="0")
    else:
        print("Error: executable path not found.")
else:
    comm = UnityCommunication()

# %% [markdown]
# # Starting and Visualizing Scenes

# %% [markdown]
# After initalizing the simulation. We can interact with the environments provided in VirtualHome. The simulator is composed of 50 human designed apartments, a sample of environments can be seen here.

# %%
# The environments are numbered 0 to 50, let's visualize a few
views = []
for scene_id in tqdm(range(10)):
    comm.reset(scene_id)
    
    # We will go over the line below later
    comm.remove_terrain()
    top_view = get_scene_cameras(comm, [-1])
    views += top_view
    
IPython.display.display(display_grid_img(views, nrows=2))

# %% [markdown]
# # Procedural Generation

# %% [markdown]
# VirtualHome also has support for procedural generation where we can generate completely new environments during runtime.

# %%
views = []
for proc_gen_seed in tqdm(range(10)):
    comm.procedural_generation(proc_gen_seed)
    
    # We will go over the line below later
    comm.remove_terrain()
    top_view = get_scene_cameras(comm, [-1])
    views += top_view
    
IPython.display.display(display_grid_img(views, nrows=2))

# %% [markdown]
# ## Scene start and display

# %% [markdown]
# We will start scene number 4 and visualize it from different views. We start it by calling reset. Scenes are numbered from 0 to 49.

# %%
comm.reset(0)

# %% [markdown]
# Each scene has multiple cameras, we will take screenshots for some of the cameras in this scene, specified by indices.

# %%
indices = [3, 32, -5, -1, -20, 15, 48, -8, 50, 17]
img_final = display_scene_cameras(comm, indices, nrows=2)
IPython.display.display(img_final)

# %% [markdown]
# ## VirtualHome supports multiple modalities

# %% [markdown]
# The cameras can also display other modalities, such as semantic segmentation, depth, instance segmentation or optical flow when playing videos. We will display a few of those here.

# %%
indices = [-20, 1, 48, -8, 17]
img_final = display_scene_modalities(
    comm, 
    indices, 
    modalities=['normal', 'seg_class', 'seg_inst', 'depth', 'surf_normals'], nrows=5)
IPython.display.display(img_final)

# %% [markdown]
# ## Including cameras

# %% [markdown]
# You can also add new cameras in the scene and get screenshots from those

# %%
# specify the position and rotation of the camera
comm.add_camera(position=[-3,1.8,-4], rotation=[20, 120, 0], field_view=60)

# Get the last camera
s, c = comm.camera_count()
img_final = display_scene_cameras(comm, [c-1], nrows=1)
IPython.display.display(img_final)

# %% [markdown]
# We can also update existing cameras, here we will update the camera we just added

# %%
# specify the position and rotation of the camera
comm.update_camera(c-1, position=[-3,1.8,-4], rotation=[20, 120, 0], field_view=80)

# Get the last camera
s, c = comm.camera_count()
img_final = display_scene_cameras(comm, [c-1], nrows=1)
IPython.display.display(img_final)

# %% [markdown]
# ## Visualizing the scene as a graph

# %% [markdown]
# Each scene in VirtualHome can be visualized as a graph, allowing to query the objects appearing, and their relationships. We start by obtaining the graph from the current scene.

# %%
s, graph = comm.environment_graph()

# %% [markdown]
# The graph is a dictionary with `nodes` and `edges`. Each node corresponds to an object and contains information such as.
# - class_name: the object_name
# - states: in which state the object is
# - id: a number you can use to perform actions over the object

# %% [markdown]
# Let's print one of the nodes, to see more of the information

# %%
graph['nodes'][140]

# %% [markdown]
# The edges connect object ids with spatial relationships, such as `INSIDE`, `ON`, `CLOSE`. You can check more of them in the `simulation` folder.

# %%
graph['edges'][:5]

# %% [markdown]
# The graph also contains bounding box and center information, which may be useful to reason about the environment layout.

# %% [markdown]
# # Modifying your environment and preparing for activities

# %% [markdown]
# In the previous section we viewed how to read and visualize the environment. Now we are interested in modifying the environment to perform activities in them.

# %% [markdown]
# ## Get default environment

# %% [markdown]
# All the environments have a default setting. We can go to this setting by calling reset()

# %%
comm.reset(4)

# %% [markdown]
# ## Adding Objects

# %% [markdown]
# We will start by adding objects to interact with in the environments. We can start by adding a cat in the environment.

# %% [markdown]
# ### Adding a cat

# %% [markdown]
# We first want to make sure that the cat will be added in the current environment. Let's say that we want to add it in one of the sofas.

# %%
imgs_prev = get_scene_cameras(comm, [-4])
display_grid_img(imgs_prev, nrows=1)

# %% [markdown]
# We start by reading the graph and looking for one of the sodas in the scene.

# %%
success, graph = comm.environment_graph()
sofa = find_nodes(graph, class_name='sofa')[-2]
print(sofa)

# %% [markdown]
# We now add one node with id `1000` of type cat, and an edge between the sofa node and the cat, specifying that the cat should be on the sofa.

# %%
add_node(graph, {'class_name': 'cat', 
                   'category': 'Animals', 
                   'id': 1000, 
                   'properties': [], 
                   'states': []})
add_edge(graph, 1000, 'ON', sofa['id'])

# %% [markdown]
# #### Update environment

# %% [markdown]
# The graph is now updated, but now we have to call the simulator so that the environment gets updated with the graph. Let's do it.

# %%
success, message = comm.expand_scene(graph)

# %% [markdown]
# You can now take an image of the environment, you will see how there has been a cat added in the environment

# %%
imgs_final = get_scene_cameras(comm, [-4])
display_grid_img(imgs_prev+imgs_final, nrows=1)

# %%
imgs_prev = imgs_final

# %% [markdown]
# ### Opening fridge

# %% [markdown]
# We may not want to add any new object, but just to change the state of the current objects. We can do this very similarly, by changing the environment graph. Let's say we want to open the fridge.

# %% [markdown]
# We read again the graph

# %%
comm=UnityCommunication()
comm.reset(2)
# Out:
# (True, '')

# %%
success, graph = comm.environment_graph()

# %% [markdown]
# We find the node `fridge` and change its `states` to open.

# %%
fridge = find_nodes(graph, class_name='fridge')[0]

# %%
fridge['states'] = ['OPEN']

# %% [markdown]
# We finally expand the graph, as we did before.

# %%
success = comm.expand_scene(graph)

# %%
imgs_final = get_scene_cameras(comm, [-4])
display_grid_img(imgs_prev+imgs_final, nrows=1)

# %% [markdown]
# ### Appliances

# %% [markdown]
# We will use the same method as before to change the state of some appliances. Again just by modifying the state of the graph.

# %% [markdown]
# We take a picture of the apartment to see how it looks before doing any change

# %%
indices = [0]
imgs_prev = get_scene_cameras(comm, indices)
display_grid_img(imgs_prev, nrows=1)

# %% [markdown]
# We now get the graph of the environment, and select a TV and a light

# %%
success, graph = comm.environment_graph()
prev_graph = graph
tv_node = [x for x in graph['nodes'] if x['class_name'] == 'tv'][0]
light_node = [x for x in graph['nodes'] if x['class_name'] == 'lightswitch'][0]

# %% [markdown]
# We change the state and modify the scene with the new graph.

# %%
tv_node['states'] = ['ON']
light_node['states'] = ['OFF']
_ = comm.expand_scene(graph)
last_graph = graph

# %% [markdown]
# We visualize the final scene

# %%
imgs_final = get_scene_cameras(comm, indices)
display_grid_img(imgs_prev+imgs_final, nrows=1)

# %% [markdown]
# ### Setting up time

# %% [markdown]
# VirtualHome also includes a real-time management system based on the 24 hour system and assign tasks to agents depending on the time of day. Furthermore the time also affects the sun's position in the sky which has a direct effect on the outdoor lighting and indoor lighting through the windows.

# %%
comm.reset(2)

# %%
views = []
s, message = comm.add_camera(position=[-9.2,1.3,-3], rotation=[15, 130, 0], field_view=60)
cam_id = int(message.split(':')[1])
# Set time to 05:30 
comm.set_time(hours=10, minutes=30, seconds=0)
morning_view = get_scene_cameras(comm, [cam_id])
views += morning_view

# Set time to 8:30 
comm.set_time(hours=15, minutes=30, seconds=0)
day_view = get_scene_cameras(comm, [cam_id])
views += day_view

# Set time to 21:00 
comm.set_time(hours=21, minutes=0, seconds=0)
night_view = get_scene_cameras(comm, [cam_id])
views += night_view
    
IPython.display.display(display_grid_img(views, nrows=1))

# %% [markdown]
# We can also deactivate the time and the forests outside, if we want

# %%
comm.reset(0)
comm.remove_terrain()
no_day_view = get_scene_cameras(comm, [17])
IPython.display.display(display_grid_img(no_day_view, nrows=1))

# %% [markdown]
# # Generating Scripts

# %% [markdown]
# We now can start scenes, visualize them and modify them. The last step is to perform activities in them. We do this by defining scripts: Lists of instructions that will be executed in sequence. Each instruction contains an action, an object, and an id. The id should match with the `id` of each of the nodes in the environment graph.

# %% [markdown]
# You can check the list of actions currently implemented [here](https://github.com/xavierpuigf/virtualhome/tree/master/simulation#actions)

# %% [markdown]
# ### Adding a character

# %% [markdown]
# The first step is to add agents in the environment, that will be performing the activity. You can specify which agent you want to add and the room where you want to add it

# %%
comm=UnityCommunication()

# %%
comm.reset(4)
comm.add_character('chars/Female2', initial_room='bedroom')
s, graph = comm.environment_graph()

# %%
# comm.place_sensors(4)

comm.add_sensors(4)
# Out:
# (True,
#  {'MotionSensors': ['Sensor ID: MotionSensor_PRE_ROO_Livingroom_04_82404057-e8f5-4a86-b896-90b0ec04142e, Room: PRE_ROO_Livingroom_04, Position: (-2.39, 2.20, 1.02), Detection Radius: 5',
#    'Sensor ID: MotionSensor_PRE_ROO_Kitchen_04_971eef7a-6b34-4b53-bd67-7c8234dfc505, Room: PRE_ROO_Kitchen_04, Position: (1.87, 2.22, 0.97), Detection Radius: 5',
#    'Sensor ID: MotionSensor_PRE_ROO_Kitchen_04_61997705-9ba3-4014-9a3f-9640732313d3, Room: PRE_ROO_Kitchen_04, Position: (7.20, 2.22, -5.93), Detection Radius: 5',
#    'Sensor ID: MotionSensor_PRE_ROO_Bedroom_04_eea028be-b68b-46c4-8407-e28086ccb1af, Room: PRE_ROO_Bedroom_04, Position: (0.34, 2.20, -5.64), Detection Radius: 5',
#    'Sensor ID: MotionSensor_PRE_ROO_Bathroom_04_24402503-7d14-4b73-bac0-9c339f38acdc, Room: PRE_ROO_Bathroom_04, Position: (0.25, 2.21, 6.06), Detection Radius: 5'],
#   'ApplianceSensors': ['Sensor ID: ApplianceSensor_desk_d1bcc0ed-5dc4-4b1b-8fe5-f2c996701213, Position: (1.89, 0.00, -0.70), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_nightstand_30e7f032-50ee-483a-b0da-b09757d5d7d7, Position: (-0.23, 0.00, 0.91), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_closet_27a1fa66-5628-4c4e-8de8-ecf66b35c5df, Position: (-1.28, 0.00, 0.88), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_b01a9f6f-12fc-44d5-9a06-6c25891a72a4, Position: (-1.43, 0.84, 0.89), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_bb6c9b11-c3fa-45a3-ad97-ad35caf3a07e, Position: (-1.81, 0.84, 0.89), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_e65e4088-83d9-40a7-aaa3-fac7a7b56374, Position: (-0.91, 0.61, 0.84), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_7b49898d-180b-4c89-814d-2b00796f6f6c, Position: (-0.91, 0.38, 0.84), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_1aac20f4-a35c-499d-a11c-273c74829c3e, Position: (-1.36, 0.61, 0.89), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_bd38f197-aa11-4395-bb6d-5dab908cb0eb, Position: (-1.64, 0.61, 0.88), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_b9a9b9ce-7589-4bfb-b30a-5e76df2ec96d, Position: (-1.91, 0.61, 0.89), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_4ec7dca2-fa58-41eb-b424-5acda8aa4b4e, Position: (-1.91, 0.38, 0.89), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_02c68d47-2c86-48d7-a6ed-0f4df30d14ec, Position: (-1.64, 0.38, 0.92), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_918dd478-6f78-4bce-a990-e0fb64ed2d7a, Position: (-1.36, 0.38, 0.88), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_5308d92e-dce2-41bc-a96d-df7580385e7f, Position: (-0.90, 0.15, 0.85), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_d690246b-7ffa-4381-a3dc-a1bcf0820fbe, Position: (-1.34, 0.15, 0.80), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_47f01e1f-24e0-4dd1-aeb7-fb22f1d6d650, Position: (-1.55, 0.15, 0.80), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_e3ca9232-2fa5-48ca-9aca-5daf57770ca2, Position: (-1.76, 0.15, 0.85), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_6f9b32c3-365b-4c68-b97f-fe77536cab9c, Position: (-1.97, 0.15, 0.81), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_tablelamp_2f864c1f-1e99-4e97-aa38-878d218f2773, Position: (2.19, 0.93, -0.05), Last Known States: ON',
#    'Sensor ID: ApplianceSensor_book_04e232fd-5898-4032-a4fb-2bbad161fab9, Position: (-0.07, 1.75, -3.57), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_book_8b98ef2d-286e-4363-88b6-dabc95ffeb50, Position: (0.25, 1.75, -3.53), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_hairproduct_f6b61037-ce35-4549-ae46-3bfb18786ade, Position: (1.36, 1.75, -3.58), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_hairproduct_2bd20e29-9cca-4582-89ea-2d710506cfcb, Position: (1.47, 1.75, -3.58), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_cellphone_fbff09d1-aafd-44f8-8345-164b87e6d53f, Position: (0.21, 1.06, -3.54), Last Known States: OFF',
#    'Sensor ID: ApplianceSensor_lightswitch_f139b295-f082-404b-9a17-97f742b156a4, Position: (2.45, 1.31, -3.07), Last Known States: ON',
#    'Sensor ID: ApplianceSensor_tv_03904259-4b2c-4864-8420-496c88db607e, Position: (0.08, 0.34, -2.39), Last Known States: OFF',
#    'Sensor ID: ApplianceSensor_computer_00edb46e-3eb8-455a-990a-7cc6cecb70da, Position: (1.77, 0.00, -1.41), Last Known States: OFF',
#    'Sensor ID: ApplianceSensor_remotecontrol_f6427896-e4c3-4667-a75b-cff38879483e, Position: (-0.03, 0.34, -2.89), Last Known States: OFF',
#    'Sensor ID: ApplianceSensor_door_7de2dd47-2e74-4f62-9f26-7f7cba905862, Position: (2.46, 1.00, -2.04), Last Known States: OPEN',
#    'Sensor ID: ApplianceSensor_kitchencabinet_a5525ca6-c1b8-43fe-aec0-6e80b5fc2eb1, Position: (5.96, 2.05, 0.90), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_kitchencabinet_b1d0959a-4541-4a6f-97fe-64480ad04e10, Position: (5.21, 2.05, 0.90), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_kitchencabinet_292059d3-1247-4cd9-8f3f-b252793edf46, Position: (4.46, 2.05, 0.90), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_kitchencabinet_674a0545-f132-4e77-9774-e74cf6d57365, Position: (3.71, 2.05, 0.90), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_kitchencabinet_5e5f094e-8e6c-489e-8e15-27a7a68a103c, Position: (7.07, 2.05, -1.67), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_kitchencabinet_86810f6c-8d8a-4ff4-b896-2416c7338417, Position: (7.07, 2.05, -0.92), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_kitchencabinet_ad86e659-620b-4038-9db2-a95aeb96266b, Position: (7.07, 2.05, -0.17), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_kitchencabinet_5c0ed70b-5672-45ce-890d-7f0dba529583, Position: (7.07, 2.05, 0.58), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_faucet_ed77a66a-4c47-4a21-95d1-cfe1b95b2346, Position: (7.34, 1.10, -1.10), Last Known States: OFF',
#    'Sensor ID: ApplianceSensor_stove_b83c4a31-6486-4836-94c9-91ebd1165956, Position: (3.10, 0.00, 0.72), Last Known States: OFF, CLOSED',
#    'Sensor ID: ApplianceSensor_dishwasher_e7f68121-5467-453d-994b-671fdf25e586, Position: (5.17, 0.00, 0.84), Last Known States: CLOSED, OFF',
#    'Sensor ID: ApplianceSensor_fridge_af6aa3ec-6745-4f4b-b336-d9671388f8da, Position: (7.07, 0.00, -3.06), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_toaster_01035d9c-6077-4797-adf5-99594fe9c1a0, Position: (7.12, 1.07, 0.16), Last Known States: OFF',
#    'Sensor ID: ApplianceSensor_coffeemaker_37d9e9a5-7807-4032-bceb-7af430ea5e20, Position: (7.11, 1.07, 0.66), Last Known States: CLOSED, OFF',
#    'Sensor ID: ApplianceSensor_microwave_ddc546d5-bf78-4e3c-9c82-db5e9bfd2817, Position: (5.03, 1.07, 0.76), Last Known States: CLOSED, OFF',
#    'Sensor ID: ApplianceSensor_clothespile_81ac49bf-b7e9-49ad-8e50-108cb41d46ff, Position: (2.67, 0.77, -4.35), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_00989dff-f1c6-4d49-834c-a8207ea70219, Position: (2.67, 0.77, -5.06), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_cookingpot_2c14ced9-e681-48ec-9395-8a838aa1b3fe, Position: (3.30, 1.07, 0.59), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_box_b168be8e-ca91-432d-a04e-48b602862680, Position: (5.42, 1.21, -6.05), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_cellphone_94c303b4-586f-4841-9e8e-8c0e9390562e, Position: (6.79, 1.08, -0.38), Last Known States: OFF',
#    'Sensor ID: ApplianceSensor_folder_fc5e16cd-a134-4cee-ac40-b3dea1ba2158, Position: (2.69, 1.30, -4.96), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_folder_0c830a60-5e6d-4353-b030-b218cf2e775e, Position: (2.69, 1.30, -5.05), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_folder_1c681977-717c-4082-b7c8-9a4bf209bafd, Position: (2.69, 1.30, -5.14), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_folder_f6b44fc3-5969-49d5-8aae-06c2c4d9af1c, Position: (2.66, 0.92, -5.43), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_folder_25c24a7e-ad08-448f-8abd-74ea97e120cf, Position: (2.66, 0.93, -5.51), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_coffeepot_82ba6704-47bf-4d0d-8ba8-825f2e815fbd, Position: (4.55, 0.84, -1.67), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_wallphone_8aa09c27-0e75-4ec3-8d8d-a1c7e967dc11, Position: (2.55, 1.33, -1.51), Last Known States: OFF',
#    'Sensor ID: ApplianceSensor_tv_0694127d-319e-427e-aa47-55b9ab80676e, Position: (5.18, 0.35, -4.84), Last Known States: OFF',
#    'Sensor ID: ApplianceSensor_lightswitch_8366b585-e7f4-4bef-b7ea-5542938ca28b, Position: (4.40, 1.12, -6.18), Last Known States: ON',
#    'Sensor ID: ApplianceSensor_tablelamp_a793cce2-4502-48b4-a592-9f6048f75f5d, Position: (2.68, 0.49, -6.69), Last Known States: ON',
#    'Sensor ID: ApplianceSensor_door_252745b2-2978-44b3-b929-09f3c08afbd8, Position: (4.19, 1.00, -6.20), Last Known States: OPEN',
#    'Sensor ID: ApplianceSensor_book_5dafb242-4c76-4094-beca-1a4d21694648, Position: (2.38, 1.51, -11.00), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_lightswitch_5665c59b-3f08-4e79-b191-db95dde83e6c, Position: (3.15, 1.20, -6.28), Last Known States: ON',
#    'Sensor ID: ApplianceSensor_radio_23210971-6b5d-4f2f-9632-376bc4494cc8, Position: (0.33, 1.22, -9.46), Last Known States: OFF',
#    'Sensor ID: ApplianceSensor_closet_fc13d682-8a94-4c5d-9d9f-aae6fe09d47e, Position: (4.62, 0.00, -7.43), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_804352ad-b52d-4c53-b82a-217a53da55a8, Position: (4.62, 0.61, -7.35), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_81864a20-3fb5-479e-a985-6abc32c1ff59, Position: (4.62, 0.61, -7.07), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_b7e69683-4cec-41ca-8fdc-28588f992615, Position: (4.63, 0.61, -6.79), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_bbe41286-dba5-43a4-8f32-882840ac96b9, Position: (4.63, 0.38, -6.80), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_4d393ba4-daa9-414a-8e4d-89a6c7e4084d, Position: (4.66, 0.38, -7.07), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_nightstand_8d85c7b5-380c-4d54-ab40-c81c29c5dc63, Position: (2.68, 0.00, -6.68), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_cabinet_473a7056-78ab-46e9-93ea-4d3fba51416f, Position: (0.29, 0.01, -9.39), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_door_4fa59117-0ce5-4441-ac07-f890167335df, Position: (1.67, 1.00, 1.29), Last Known States: OPEN',
#    'Sensor ID: ApplianceSensor_curtains_67260c44-535c-493c-bcbb-af11d4f6d640, Position: (4.13, 0.00, 2.70), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_toilet_22af8323-95c6-4c7d-8ac4-9d8d79481ba3, Position: (4.15, -0.15, 6.10), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_bathroomcabinet_4f230240-fd12-4126-b890-fd167a0d5616, Position: (1.69, 0.00, 6.13), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_faucet_0cfc4ec3-8392-43bb-b56b-35201811c2d7, Position: (1.72, 1.01, 6.14), Last Known States: OFF',
#    'Sensor ID: ApplianceSensor_closet_6182f72a-3caf-42ab-9ac9-9ed72fbbbaa1, Position: (0.33, 0.00, 2.18), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_closet_5c6f5b93-b944-468e-8992-493b9e715d5d, Position: (0.33, 0.00, 3.68), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_39c73cd5-c503-4425-bde3-2637c7717f86, Position: (0.37, 0.61, 4.06), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_1cc93894-4534-4cab-9a4b-25fd6f8824c1, Position: (0.33, 0.61, 3.61), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_d93aad33-4f44-4071-a202-1ce29f8a9384, Position: (0.32, 0.61, 3.05), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_860abd2f-d5a1-4360-afe9-c915190206f0, Position: (0.32, 0.38, 3.06), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_c59ea342-fa2f-481d-b9bd-835aecb21eff, Position: (0.33, 0.38, 3.60), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_clothespile_781f52a7-3688-4fc6-b48d-b4c9e7d937be, Position: (0.37, 0.15, 4.06), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_hairproduct_5a3881c4-9e4b-4fa9-9d49-b55a8b453605, Position: (4.85, 0.65, 2.10), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_hairproduct_b0f1e238-7edb-4dea-b054-d927054a1e95, Position: (4.86, 0.65, 1.99), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_toothpaste_d0983f11-e8cb-4862-bd71-f81f36c230a3, Position: (2.08, 0.98, 5.98), Last Known States: CLOSED',
#    'Sensor ID: ApplianceSensor_lightswitch_41a105b4-46c0-4754-8819-3f3223b195bb, Position: (1.79, 1.25, 1.30), Last Known States: ON',
#    'Sensor ID: ApplianceSensor_washingmachine_9f7e991e-a849-44a2-8301-4da48411f16e, Position: (0.31, 0.00, 4.75), Last Known States: CLOSED, OFF']})

# %%
door_nodes =[node for node in graph['nodes'] if  node['class_name'] =='door']
door_nodes
# Out:
# [{'id': 130,
#   'category': 'Doors',
#   'class_name': 'door',
#   'prefab_name': 'PRE_DOO_Door_01_03',
#   'obj_transform': {'position': [2.45699978, 0.995, -2.03799987],
#    'rotation': [0.0, -0.740998, 0.0, 0.6715072],
#    'scale': [1.0, 1.0, 1.0]},
#   'bounding_box': {'center': [2.500357, 0.5, -2.50000381],
#    'size': [0.9283972, 1.0, 0.9283972]},
#   'properties': ['CAN_OPEN'],
#   'states': ['OPEN']},
#  {'id': 243,
#   'category': 'Doors',
#   'class_name': 'door',
#   'prefab_name': 'PRE_DOO_Door_01_03',
#   'obj_transform': {'position': [4.1915, 0.995, -6.199001],
#    'rotation': [0.0, 0.259257436, 0.0, 0.9658083],
#    'scale': [1.0, 1.0, 1.0]},
#   'bounding_box': {'center': [3.75849628, 0.5, -6.23135757],
#    'size': [0.9283972, 1.0, 0.9283972]},
#   'properties': ['CAN_OPEN'],
#   'states': ['OPEN']},
#  {'id': 290,
#   'category': 'Doors',
#   'class_name': 'door',
#   'prefab_name': 'PRE_DOO_Door_01_03',
#   'obj_transform': {'position': [1.67400038, 0.995, 1.28800058],
#    'rotation': [0.0, 0.295097977, 0.0, 0.955467045],
#    'scale': [1.0, 1.0, 1.0]},
#   'bounding_box': {'center': [1.24100447, 0.5, 1.24845731],
#    'size': [0.9283974, 1.0, 0.9283974]},
#   'properties': ['CAN_OPEN'],
#   'states': ['OPEN']}]

# %%
room_nodes = [node for node in graph['nodes'] if node['category']=='Rooms' ]

for node in room_nodes:
    print(node)
# Out:
# {'id': 11, 'category': 'Rooms', 'class_name': 'livingroom', 'prefab_name': 'PRE_ROO_Livingroom_04', 'obj_transform': {'position': [0.0, 0.0, 0.0], 'rotation': [0.0, 0.0, 0.0, 1.0], 'scale': [1.0, 1.0, 1.0]}, 'bounding_box': {'center': [0.0, 1.25, -1.25], 'size': [5.5, 3.0, 5.5]}, 'properties': [], 'states': []}
# {'id': 111, 'category': 'Rooms', 'class_name': 'kitchen', 'prefab_name': 'PRE_ROO_Kitchen_04', 'obj_transform': {'position': [7.5, 0.0, 0.022], 'rotation': [0.0, 0.0, 0.0, 1.0], 'scale': [1.0, 1.0, 1.0]}, 'bounding_box': {'center': [5.0, 1.25, -2.478], 'size': [5.5, 3.0, 8.0]}, 'properties': [], 'states': []}
# {'id': 214, 'category': 'Rooms', 'class_name': 'bedroom', 'prefab_name': 'PRE_ROO_Bedroom_04', 'obj_transform': {'position': [1.2935, 0.0, -11.228], 'rotation': [0.0, 0.7071068, 0.0, 0.7071067], 'scale': [1.0, 1.0, 1.0]}, 'bounding_box': {'center': [2.5435, 1.25, -8.728001], 'size': [5.5, 3.0, 5.5]}, 'properties': [], 'states': []}
# {'id': 276, 'category': 'Rooms', 'class_name': 'bathroom', 'prefab_name': 'PRE_ROO_Bathroom_04', 'obj_transform': {'position': [1.206, 0.0, 6.25], 'rotation': [0.0, -0.7071068, 0.0, 0.7071067], 'scale': [1.0, 1.0, 1.0]}, 'bounding_box': {'center': [2.456, 1.25, 3.75000048], 'size': [5.5, 3.0, 5.5]}, 'properties': [], 'states': []}

# %%
for node in graph['nodes']:
    if node['class_name']=='fridge':

        print(f"Node {node} \n")
# Out:
# Node {'id': 157, 'category': 'Appliances', 'class_name': 'fridge', 'prefab_name': 'PRE_APP_Fridge_01_04', 'obj_transform': {'position': [7.068905, 0.0, -3.062123], 'rotation': [0.0, 1.0, 0.0, 3.57627869e-07], 'scale': [1.0, 1.0, 1.0]}, 'bounding_box': {'center': [7.079718, 1.06257987, -3.06155133], 'size': [0.7121659, 2.125163, 0.8896628]}, 'properties': ['CAN_OPEN', 'HAS_SWITCH', 'CONTAINERS', 'HAS_PLUG'], 'states': ['CLOSED']}

# %%
        # '<char0> [Open] <door> ({})'.format(130),
        # '<char0> [Close] <door> ({})'.format(130),
        # '<char0> [Walk] <bedroom> ({})'.format(214),
        # '<char0> [Walk] <bathroom> ({})'.format(276),



        #   '<char0> [Find] <cat> ({})'.format(cat_id),
        #   '<char0> [Grab] <cat> ({})'.format(cat_id),
        #   '<char0> [Sit] <sofa> ({})'.format(sofa['id'])]

# script for appliances
script=[
    '<char0> [Walk] <kitchen> ({})'.format(111),
    '<char0> [Open] <fridge> ({})'.format(157)
    
]
success, updated_graph = comm.render_script(script=script,
                                      processing_time_limit=60,
                                      find_solution=True,
                                      image_width=320,
                                      image_height=240,  
                                      skip_animation=False,
                                      recording=True,
                                      save_pose_data=True,file_name_prefix='a6_goto_kitchen_open_fridge_sol_true'
                                      ,
                                      output_folder='/home/yusuf/Desktop/megha/virtualhome-master/virtualhome/rendered_output'
                                      )

# %%
updated_graph
# Out:
# [{'nodeId': 1, 'className': 'character', 'states': []},
#  {'nodeId': 11, 'className': 'livingroom', 'states': []},
#  {'nodeId': 12, 'className': 'floor', 'states': []},
#  {'nodeId': 13, 'className': 'floor', 'states': []},
#  {'nodeId': 14, 'className': 'floor', 'states': []},
#  {'nodeId': 15, 'className': 'floor', 'states': []},
#  {'nodeId': 16, 'className': 'wall', 'states': []},
#  {'nodeId': 17, 'className': 'wall', 'states': []},
#  {'nodeId': 18, 'className': 'wall', 'states': []},
#  {'nodeId': 19, 'className': 'wall', 'states': []},
#  {'nodeId': 20, 'className': 'ceiling', 'states': []},
#  {'nodeId': 21, 'className': 'ceiling', 'states': []},
#  {'nodeId': 22, 'className': 'ceiling', 'states': []},
#  {'nodeId': 23, 'className': 'ceiling', 'states': []},
#  {'nodeId': 24, 'className': 'doorjamb', 'states': []},
#  {'nodeId': 25, 'className': 'doorjamb', 'states': []},
#  {'nodeId': 26, 'className': 'doorjamb', 'states': []},
#  {'nodeId': 27, 'className': 'sofa', 'states': []},
#  {'nodeId': 28, 'className': 'chair', 'states': []},
#  {'nodeId': 29, 'className': 'desk', 'states': [0]},
#  {'nodeId': 30, 'className': 'tvstand', 'states': []},
#  {'nodeId': 31, 'className': 'wallshelf', 'states': []},
#  {'nodeId': 32, 'className': 'wallshelf', 'states': []},
#  {'nodeId': 33, 'className': 'wallshelf', 'states': []},
#  {'nodeId': 34, 'className': 'wallshelf', 'states': []},
#  {'nodeId': 35, 'className': 'nightstand', 'states': [0]},
#  {'nodeId': 36, 'className': 'closet', 'states': [0]},
#  {'nodeId': 37, 'className': 'hanger', 'states': []},
#  {'nodeId': 38, 'className': 'clothesshirt', 'states': []},
#  {'nodeId': 39, 'className': 'hanger', 'states': []},
#  {'nodeId': 40, 'className': 'clothespants', 'states': []},
#  {'nodeId': 41, 'className': 'hanger', 'states': []},
#  {'nodeId': 42, 'className': 'clothesshirt', 'states': []},
#  {'nodeId': 43, 'className': 'hanger', 'states': []},
#  {'nodeId': 44, 'className': 'clothespants', 'states': []},
#  {'nodeId': 45, 'className': 'hanger', 'states': []},
#  {'nodeId': 46, 'className': 'clothespants', 'states': []},
#  {'nodeId': 47, 'className': 'hanger', 'states': []},
#  {'nodeId': 48, 'className': 'clothespants', 'states': []},
#  {'nodeId': 49, 'className': 'hanger', 'states': []},
#  {'nodeId': 50, 'className': 'clothespants', 'states': []},
#  {'nodeId': 51, 'className': 'hanger', 'states': []},
#  {'nodeId': 52, 'className': 'clothesshirt', 'states': []},
#  {'nodeId': 53, 'className': 'hanger', 'states': []},
#  {'nodeId': 54, 'className': 'hanger', 'states': []},
#  {'nodeId': 55, 'className': 'hanger', 'states': []},
#  {'nodeId': 56, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 57, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 58, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 59, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 60, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 61, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 62, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 63, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 64, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 65, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 66, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 67, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 68, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 69, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 70, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 71, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 72, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 73, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 74, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 75, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 76, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 77, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 78, 'className': 'tablelamp', 'states': [2]},
#  {'nodeId': 79, 'className': 'ceilinglamp', 'states': []},
#  {'nodeId': 80, 'className': 'walllamp', 'states': []},
#  {'nodeId': 81, 'className': 'wallpictureframe', 'states': []},
#  {'nodeId': 82, 'className': 'orchid', 'states': []},
#  {'nodeId': 83, 'className': 'rug', 'states': []},
#  {'nodeId': 84, 'className': 'rug', 'states': []},
#  {'nodeId': 85, 'className': 'pillow', 'states': []},
#  {'nodeId': 86, 'className': 'pillow', 'states': []},
#  {'nodeId': 87, 'className': 'wallpictureframe', 'states': []},
#  {'nodeId': 88, 'className': 'book', 'states': [0]},
#  {'nodeId': 89, 'className': 'book', 'states': [0]},
#  {'nodeId': 90, 'className': 'hairproduct', 'states': [0]},
#  {'nodeId': 91, 'className': 'hairproduct', 'states': [0]},
#  {'nodeId': 92, 'className': 'facecream', 'states': []},
#  {'nodeId': 93, 'className': 'deodorant', 'states': []},
#  {'nodeId': 94, 'className': 'photoframe', 'states': []},
#  {'nodeId': 95, 'className': 'wineglass', 'states': []},
#  {'nodeId': 96, 'className': 'waterglass', 'states': []},
#  {'nodeId': 97, 'className': 'cupcake', 'states': []},
#  {'nodeId': 98, 'className': 'plate', 'states': []},
#  {'nodeId': 99, 'className': 'mug', 'states': []},
#  {'nodeId': 100, 'className': 'plate', 'states': []},
#  {'nodeId': 101, 'className': 'cellphone', 'states': [3]},
#  {'nodeId': 102, 'className': 'powersocket', 'states': []},
#  {'nodeId': 103, 'className': 'lightswitch', 'states': [2]},
#  {'nodeId': 104, 'className': 'keyboard', 'states': []},
#  {'nodeId': 105, 'className': 'mouse', 'states': []},
#  {'nodeId': 106, 'className': 'mousemat', 'states': []},
#  {'nodeId': 107, 'className': 'cpuscreen', 'states': []},
#  {'nodeId': 108, 'className': 'tv', 'states': [3]},
#  {'nodeId': 109, 'className': 'computer', 'states': [3]},
#  {'nodeId': 110, 'className': 'remotecontrol', 'states': [3]},
#  {'nodeId': 111, 'className': 'kitchen', 'states': []},
#  {'nodeId': 112, 'className': 'floor', 'states': []},
#  {'nodeId': 113, 'className': 'floor', 'states': []},
#  {'nodeId': 114, 'className': 'floor', 'states': []},
#  {'nodeId': 115, 'className': 'floor', 'states': []},
#  {'nodeId': 116, 'className': 'floor', 'states': []},
#  {'nodeId': 117, 'className': 'floor', 'states': []},
#  {'nodeId': 118, 'className': 'wall', 'states': []},
#  {'nodeId': 119, 'className': 'wall', 'states': []},
#  {'nodeId': 120, 'className': 'wall', 'states': []},
#  {'nodeId': 121, 'className': 'wall', 'states': []},
#  {'nodeId': 122, 'className': 'wall', 'states': []},
#  {'nodeId': 123, 'className': 'wall', 'states': []},
#  {'nodeId': 124, 'className': 'ceiling', 'states': []},
#  {'nodeId': 125, 'className': 'ceiling', 'states': []},
#  {'nodeId': 126, 'className': 'ceiling', 'states': []},
#  {'nodeId': 127, 'className': 'ceiling', 'states': []},
#  {'nodeId': 128, 'className': 'ceiling', 'states': []},
#  {'nodeId': 129, 'className': 'ceiling', 'states': []},
#  {'nodeId': 130, 'className': 'door', 'states': [1]},
#  {'nodeId': 131, 'className': 'doorjamb', 'states': []},
#  {'nodeId': 132, 'className': 'wallshelf', 'states': []},
#  {'nodeId': 133, 'className': 'tvstand', 'states': []},
#  {'nodeId': 134, 'className': 'chair', 'states': []},
#  {'nodeId': 135, 'className': 'chair', 'states': []},
#  {'nodeId': 136, 'className': 'chair', 'states': []},
#  {'nodeId': 137, 'className': 'chair', 'states': []},
#  {'nodeId': 138, 'className': 'kitchentable', 'states': []},
#  {'nodeId': 139, 'className': 'wallshelf', 'states': []},
#  {'nodeId': 140, 'className': 'bookshelf', 'states': []},
#  {'nodeId': 141, 'className': 'sofa', 'states': []},
#  {'nodeId': 142, 'className': 'kitchencabinet', 'states': [0]},
#  {'nodeId': 143, 'className': 'kitchencabinet', 'states': [0]},
#  {'nodeId': 144, 'className': 'kitchencabinet', 'states': [0]},
#  {'nodeId': 145, 'className': 'kitchencabinet', 'states': [0]},
#  {'nodeId': 146, 'className': 'kitchencabinet', 'states': [0]},
#  {'nodeId': 147, 'className': 'kitchencabinet', 'states': [0]},
#  {'nodeId': 148, 'className': 'kitchencabinet', 'states': [0]},
#  {'nodeId': 149, 'className': 'kitchencabinet', 'states': [0]},
#  {'nodeId': 150, 'className': 'kitchencounter', 'states': [0]},
#  {'nodeId': 151, 'className': 'sink', 'states': []},
#  {'nodeId': 152, 'className': 'faucet', 'states': [3]},
#  {'nodeId': 153, 'className': 'stovefan', 'states': []},
#  {'nodeId': 154, 'className': 'stove', 'states': [3, 0]},
#  {'nodeId': 155, 'className': 'oventray', 'states': []},
#  {'nodeId': 156, 'className': 'dishwasher', 'states': [0, 3]},
#  {'nodeId': 157, 'className': 'fridge', 'states': [0]},
#  {'nodeId': 158, 'className': 'toaster', 'states': [3]},
#  {'nodeId': 159, 'className': 'breadslice', 'states': []},
#  {'nodeId': 160, 'className': 'breadslice', 'states': []},
#  {'nodeId': 161, 'className': 'coffeemaker', 'states': [0, 3]},
#  {'nodeId': 162, 'className': 'microwave', 'states': [0, 3]},
#  {'nodeId': 163, 'className': 'dishbowl', 'states': []},
#  {'nodeId': 164, 'className': 'ceilinglamp', 'states': []},
#  {'nodeId': 165, 'className': 'ceilinglamp', 'states': []},
#  {'nodeId': 166, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 167, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 168, 'className': 'wineglass', 'states': []},
#  {'nodeId': 169, 'className': 'wineglass', 'states': []},
#  {'nodeId': 170, 'className': 'washingsponge', 'states': []},
#  {'nodeId': 171, 'className': 'dishwashingliquid', 'states': []},
#  {'nodeId': 172, 'className': 'facecream', 'states': []},
#  {'nodeId': 173, 'className': 'deodorant', 'states': []},
#  {'nodeId': 174, 'className': 'perfume', 'states': []},
#  {'nodeId': 175, 'className': 'cookingpot', 'states': [0]},
#  {'nodeId': 176, 'className': 'condimentbottle', 'states': []},
#  {'nodeId': 177, 'className': 'condimentbottle', 'states': []},
#  {'nodeId': 178, 'className': 'condimentshaker', 'states': []},
#  {'nodeId': 179, 'className': 'condimentshaker', 'states': []},
#  {'nodeId': 180, 'className': 'box', 'states': [0]},
#  {'nodeId': 181, 'className': 'photoframe', 'states': []},
#  {'nodeId': 182, 'className': 'plate', 'states': []},
#  {'nodeId': 183, 'className': 'mug', 'states': []},
#  {'nodeId': 184, 'className': 'mug', 'states': []},
#  {'nodeId': 185, 'className': 'plate', 'states': []},
#  {'nodeId': 186, 'className': 'plate', 'states': []},
#  {'nodeId': 187, 'className': 'cellphone', 'states': [3]},
#  {'nodeId': 188, 'className': 'folder', 'states': [0]},
#  {'nodeId': 189, 'className': 'folder', 'states': [0]},
#  {'nodeId': 190, 'className': 'folder', 'states': [0]},
#  {'nodeId': 191, 'className': 'folder', 'states': [0]},
#  {'nodeId': 192, 'className': 'folder', 'states': [0]},
#  {'nodeId': 193, 'className': 'coffeepot', 'states': [0]},
#  {'nodeId': 194, 'className': 'pillow', 'states': []},
#  {'nodeId': 195, 'className': 'pillow', 'states': []},
#  {'nodeId': 196, 'className': 'rug', 'states': []},
#  {'nodeId': 197, 'className': 'orchid', 'states': []},
#  {'nodeId': 198, 'className': 'wallpictureframe', 'states': []},
#  {'nodeId': 199, 'className': 'wallphone', 'states': [3]},
#  {'nodeId': 200, 'className': 'tv', 'states': [3]},
#  {'nodeId': 201, 'className': 'lightswitch', 'states': [2]},
#  {'nodeId': 202, 'className': 'powersocket', 'states': []},
#  {'nodeId': 203, 'className': 'bananas', 'states': []},
#  {'nodeId': 204, 'className': 'bananas', 'states': []},
#  {'nodeId': 205, 'className': 'dishbowl', 'states': []},
#  {'nodeId': 206, 'className': 'mincedmeat', 'states': []},
#  {'nodeId': 207, 'className': 'cutlets', 'states': []},
#  {'nodeId': 208, 'className': 'chocolatesyrup', 'states': []},
#  {'nodeId': 209, 'className': 'cereal', 'states': []},
#  {'nodeId': 210, 'className': 'cupcake', 'states': []},
#  {'nodeId': 211, 'className': 'cupcake', 'states': []},
#  {'nodeId': 212, 'className': 'pudding', 'states': []},
#  {'nodeId': 213, 'className': 'pie', 'states': []},
#  {'nodeId': 214, 'className': 'bedroom', 'states': []},
#  {'nodeId': 215, 'className': 'floor', 'states': []},
#  {'nodeId': 216, 'className': 'floor', 'states': []},
#  {'nodeId': 217, 'className': 'floor', 'states': []},
#  {'nodeId': 218, 'className': 'floor', 'states': []},
#  {'nodeId': 219, 'className': 'ceiling', 'states': []},
#  {'nodeId': 220, 'className': 'ceiling', 'states': []},
#  {'nodeId': 221, 'className': 'ceiling', 'states': []},
#  {'nodeId': 222, 'className': 'ceiling', 'states': []},
#  {'nodeId': 223, 'className': 'wall', 'states': []},
#  {'nodeId': 224, 'className': 'wall', 'states': []},
#  {'nodeId': 225, 'className': 'wall', 'states': []},
#  {'nodeId': 226, 'className': 'wall', 'states': []},
#  {'nodeId': 227, 'className': 'walllamp', 'states': []},
#  {'nodeId': 228, 'className': 'walllamp', 'states': []},
#  {'nodeId': 229, 'className': 'tablelamp', 'states': [2]},
#  {'nodeId': 230, 'className': 'ceilinglamp', 'states': []},
#  {'nodeId': 231, 'className': 'rug', 'states': []},
#  {'nodeId': 232, 'className': 'wallpictureframe', 'states': []},
#  {'nodeId': 233, 'className': 'wallpictureframe', 'states': []},
#  {'nodeId': 234, 'className': 'wallpictureframe', 'states': []},
#  {'nodeId': 235, 'className': 'pillow', 'states': []},
#  {'nodeId': 236, 'className': 'pillow', 'states': []},
#  {'nodeId': 237, 'className': 'pillow', 'states': []},
#  {'nodeId': 238, 'className': 'orchid', 'states': []},
#  {'nodeId': 239, 'className': 'rug', 'states': []},
#  {'nodeId': 240, 'className': 'pillow', 'states': []},
#  {'nodeId': 241, 'className': 'pillow', 'states': []},
#  {'nodeId': 242, 'className': 'doorjamb', 'states': []},
#  {'nodeId': 243, 'className': 'door', 'states': [1]},
#  {'nodeId': 244, 'className': 'book', 'states': [0]},
#  {'nodeId': 245, 'className': 'perfume', 'states': []},
#  {'nodeId': 246, 'className': 'deodorant', 'states': []},
#  {'nodeId': 247, 'className': 'facecream', 'states': []},
#  {'nodeId': 248, 'className': 'photoframe', 'states': []},
#  {'nodeId': 249, 'className': 'lightswitch', 'states': [2]},
#  {'nodeId': 250, 'className': 'powersocket', 'states': []},
#  {'nodeId': 251, 'className': 'radio', 'states': [3]},
#  {'nodeId': 252, 'className': 'wallshelf', 'states': []},
#  {'nodeId': 253, 'className': 'wallshelf', 'states': []},
#  {'nodeId': 254, 'className': 'chair', 'states': []},
#  {'nodeId': 255, 'className': 'closet', 'states': [0]},
#  {'nodeId': 256, 'className': 'hanger', 'states': []},
#  {'nodeId': 257, 'className': 'clothespants', 'states': []},
#  {'nodeId': 258, 'className': 'hanger', 'states': []},
#  {'nodeId': 259, 'className': 'clothesshirt', 'states': []},
#  {'nodeId': 260, 'className': 'hanger', 'states': []},
#  {'nodeId': 261, 'className': 'clothespants', 'states': []},
#  {'nodeId': 262, 'className': 'hanger', 'states': []},
#  {'nodeId': 263, 'className': 'clothesshirt', 'states': []},
#  {'nodeId': 264, 'className': 'hanger', 'states': []},
#  {'nodeId': 265, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 266, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 267, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 268, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 269, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 270, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 271, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 272, 'className': 'sofa', 'states': []},
#  {'nodeId': 273, 'className': 'nightstand', 'states': [0]},
#  {'nodeId': 274, 'className': 'bed', 'states': []},
#  {'nodeId': 275, 'className': 'cabinet', 'states': [0]},
#  {'nodeId': 276, 'className': 'bathroom', 'states': []},
#  {'nodeId': 277, 'className': 'floor', 'states': []},
#  {'nodeId': 278, 'className': 'floor', 'states': []},
#  {'nodeId': 279, 'className': 'floor', 'states': []},
#  {'nodeId': 280, 'className': 'floor', 'states': []},
#  {'nodeId': 281, 'className': 'wall', 'states': []},
#  {'nodeId': 282, 'className': 'wall', 'states': []},
#  {'nodeId': 283, 'className': 'wall', 'states': []},
#  {'nodeId': 284, 'className': 'wall', 'states': []},
#  {'nodeId': 285, 'className': 'ceiling', 'states': []},
#  {'nodeId': 286, 'className': 'ceiling', 'states': []},
#  {'nodeId': 287, 'className': 'ceiling', 'states': []},
#  {'nodeId': 288, 'className': 'ceiling', 'states': []},
#  {'nodeId': 289, 'className': 'doorjamb', 'states': []},
#  {'nodeId': 290, 'className': 'door', 'states': [1]},
#  {'nodeId': 291, 'className': 'walllamp', 'states': []},
#  {'nodeId': 292, 'className': 'ceilinglamp', 'states': []},
#  {'nodeId': 293, 'className': 'stall', 'states': []},
#  {'nodeId': 294, 'className': 'curtains', 'states': [0]},
#  {'nodeId': 295, 'className': 'stall', 'states': []},
#  {'nodeId': 296, 'className': 'toilet', 'states': [0]},
#  {'nodeId': 297, 'className': 'bathroomcabinet', 'states': [0]},
#  {'nodeId': 298, 'className': 'bathroomcounter', 'states': [0]},
#  {'nodeId': 299, 'className': 'sink', 'states': []},
#  {'nodeId': 300, 'className': 'faucet', 'states': [3]},
#  {'nodeId': 301, 'className': 'towelrack', 'states': []},
#  {'nodeId': 302, 'className': 'closet', 'states': [0]},
#  {'nodeId': 303, 'className': 'hanger', 'states': []},
#  {'nodeId': 304, 'className': 'hanger', 'states': []},
#  {'nodeId': 305, 'className': 'hanger', 'states': []},
#  {'nodeId': 306, 'className': 'hanger', 'states': []},
#  {'nodeId': 307, 'className': 'hanger', 'states': []},
#  {'nodeId': 308, 'className': 'hanger', 'states': []},
#  {'nodeId': 309, 'className': 'hanger', 'states': []},
#  {'nodeId': 310, 'className': 'hanger', 'states': []},
#  {'nodeId': 311, 'className': 'hanger', 'states': []},
#  {'nodeId': 312, 'className': 'hanger', 'states': []},
#  {'nodeId': 313, 'className': 'hanger', 'states': []},
#  {'nodeId': 314, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 315, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 316, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 317, 'className': 'closet', 'states': [0]},
#  {'nodeId': 318, 'className': 'hanger', 'states': []},
#  {'nodeId': 319, 'className': 'clothesshirt', 'states': []},
#  {'nodeId': 320, 'className': 'hanger', 'states': []},
#  {'nodeId': 321, 'className': 'clothespants', 'states': []},
#  {'nodeId': 322, 'className': 'hanger', 'states': []},
#  {'nodeId': 323, 'className': 'clothespants', 'states': []},
#  {'nodeId': 324, 'className': 'hanger', 'states': []},
#  {'nodeId': 325, 'className': 'clothespants', 'states': []},
#  {'nodeId': 326, 'className': 'hanger', 'states': []},
#  {'nodeId': 327, 'className': 'clothesshirt', 'states': []},
#  {'nodeId': 328, 'className': 'hanger', 'states': []},
#  {'nodeId': 329, 'className': 'hanger', 'states': []},
#  {'nodeId': 330, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 331, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 332, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 333, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 334, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 335, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 336, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 337, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 338, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 339, 'className': 'closetdrawer', 'states': []},
#  {'nodeId': 340, 'className': 'clothespile', 'states': [0]},
#  {'nodeId': 341, 'className': 'towelrack', 'states': []},
#  {'nodeId': 342, 'className': 'towel', 'states': []},
#  {'nodeId': 343, 'className': 'towel', 'states': []},
#  {'nodeId': 344, 'className': 'towel', 'states': []},
#  {'nodeId': 345, 'className': 'toiletpaper', 'states': []},
#  {'nodeId': 346, 'className': 'washingsponge', 'states': []},
#  {'nodeId': 347, 'className': 'hairproduct', 'states': [0]},
#  {'nodeId': 348, 'className': 'hairproduct', 'states': [0]},
#  {'nodeId': 349, 'className': 'slippers', 'states': []},
#  {'nodeId': 350, 'className': 'slippers', 'states': []},
#  {'nodeId': 351, 'className': 'waterglass', 'states': []},
#  {'nodeId': 352, 'className': 'toothbrush', 'states': []},
#  {'nodeId': 353, 'className': 'barsoap', 'states': []},
#  {'nodeId': 354, 'className': 'perfume', 'states': []},
#  {'nodeId': 355, 'className': 'deodorant', 'states': []},
#  {'nodeId': 356, 'className': 'facecream', 'states': []},
#  {'nodeId': 357, 'className': 'painkillers', 'states': []},
#  {'nodeId': 358, 'className': 'toothpaste', 'states': [0]},
#  {'nodeId': 359, 'className': 'towel', 'states': []},
#  {'nodeId': 360, 'className': 'towel', 'states': []},
#  {'nodeId': 361, 'className': 'wallpictureframe', 'states': []},
#  {'nodeId': 362, 'className': 'rug', 'states': []},
#  {'nodeId': 363, 'className': 'rug', 'states': []},
#  {'nodeId': 364, 'className': 'powersocket', 'states': []},
#  {'nodeId': 365, 'className': 'powersocket', 'states': []},
#  {'nodeId': 366, 'className': 'lightswitch', 'states': [2]},
#  {'nodeId': 367, 'className': 'washingmachine', 'states': [0, 3]}]

# %%
# Reset the environment
comm.reset(0)
comm.add_character('Chars/Female2')

s, graph = comm.environment_graph()
# Get nodes for salmon and microwave
salmon_id = [node['id'] for node in graph['nodes'] if node['class_name'] == 'salmon'][0]
microwave_id = [node['id'] for node in graph['nodes'] if node['class_name'] == 'microwave'][0]

print(microwave_id)

# Put salmon in microwave
script = [
    '<char0> [walk] <salmon> ({})'.format(salmon_id),
    '<char0> [grab] <salmon> ({})'.format(salmon_id),
    '<char0> [open] <microwave> ({})'.format(microwave_id),
    '<char0> [putin] <salmon> ({}) <microwave> ({})'.format(salmon_id, microwave_id),
    '<char0> [close] <microwave> ({})'.format(microwave_id),
    
]
for i, script_inst in enumerate(script):
    s,nodes =comm.render_script([script_inst], recording=True, frame_rate=10,
                    file_name_prefix=f'put_salmon_in_microwave_{i}',
                    output_folder='/home/yusuf/Desktop/megha/virtualhome-master/virtualhome/rendered_output',
                    )
    
    microwave_node = [node for node in nodes if node['nodeId']==microwave_id]
    print(microwave_node)
# Out:
# 314
# [{'nodeId': 314, 'className': 'microwave', 'states': [0, 3]}]
# [{'nodeId': 314, 'className': 'microwave', 'states': [0, 3]}]
# [{'nodeId': 314, 'className': 'microwave', 'states': [1, 3]}]
# [{'nodeId': 314, 'className': 'microwave', 'states': [1, 3]}]
# [{'nodeId': 314, 'className': 'microwave', 'states': [0, 3]}]

# %%
_, updated_graph = comm.environment_graph()

# %%
for node in updated_graph['nodes']:
    if node['class_name']=='fridge':

        print(f"Node {node} \n")
# Out:
# Node {'id': 157, 'category': 'Appliances', 'class_name': 'fridge', 'prefab_name': 'PRE_APP_Fridge_01_04', 'obj_transform': {'position': [7.068905, 0.0, -3.062123], 'rotation': [0.0, 1.0, 0.0, 3.57627869e-07], 'scale': [1.0, 1.0, 1.0]}, 'bounding_box': {'center': [7.079718, 1.06257987, -3.06155133], 'size': [0.7121659, 2.125163, 0.8896628]}, 'properties': ['CAN_OPEN', 'HAS_SWITCH', 'CONTAINERS', 'HAS_PLUG'], 'states': ['CLOSED']}

# %%
nodes = [node for node in graph['nodes'] if node['category']=="Doors" and node['class_name']=='door']

for node in nodes:
    # print(node['class_name'], node['id'])
    print(node)
# Out:
# {'id': 130, 'category': 'Doors', 'class_name': 'door', 'prefab_name': 'PRE_DOO_Door_01_03', 'obj_transform': {'position': [2.45699978, 0.995, -2.03799987], 'rotation': [0.0, -0.740998, 0.0, 0.6715072], 'scale': [1.0, 1.0, 1.0]}, 'bounding_box': {'center': [2.500357, 0.5, -2.50000381], 'size': [0.9283972, 1.0, 0.9283972]}, 'properties': ['CAN_OPEN'], 'states': ['CLOSED']}
# {'id': 243, 'category': 'Doors', 'class_name': 'door', 'prefab_name': 'PRE_DOO_Door_01_03', 'obj_transform': {'position': [4.1915, 0.995, -6.199001], 'rotation': [0.0, 0.259257436, 0.0, 0.9658083], 'scale': [1.0, 1.0, 1.0]}, 'bounding_box': {'center': [3.75849628, 0.5, -6.23135757], 'size': [0.9283972, 1.0, 0.9283972]}, 'properties': ['CAN_OPEN'], 'states': ['OPEN']}
# {'id': 290, 'category': 'Doors', 'class_name': 'door', 'prefab_name': 'PRE_DOO_Door_01_03', 'obj_transform': {'position': [1.67400038, 0.995, 1.28800058], 'rotation': [0.0, 0.295097977, 0.0, 0.955467045], 'scale': [1.0, 1.0, 1.0]}, 'bounding_box': {'center': [1.24100447, 0.5, 1.24845731], 'size': [0.9283974, 1.0, 0.9283974]}, 'properties': ['CAN_OPEN'], 'states': ['OPEN']}

# %% [markdown]
# If you count the number of cameras, you will see that a few new cameras have been added into the scene. These are cameras attached to the character. When the character moves, the cameras will move as well.

# %%
s, nc = comm.camera_count()
indices = range(nc - 6, nc)
imgs_prev = get_scene_cameras(comm, indices)
display_grid_img(imgs_prev, nrows=2)

# %% [markdown]
# ## Generating the first script

# %% [markdown]
# Let's start by interacting witht the cat and the sofa that we set up before. The cat had id 1000. The sofa was stored in a variable `sofa` containing that node. We can query its id directly. This sequence will make the agent walk to the sofa, grab the cat and sit in the sofa.

# %%
script = ['<char0> [Walk] <sofa> ({})'.format(sofa['id']),
          '<char0> [Find] <cat> ({})'.format(cat_id),
          '<char0> [Grab] <cat> ({})'.format(cat_id),
          '<char0> [Sit] <sofa> ({})'.format(sofa['id'])]

# %% [markdown]
# We now want to execute the script in the environment. We do that through render_script. Notice that we can specify a file name, which will be used to save a video with the activity.

# %%
success, message = comm.render_script(script=script,
                                      processing_time_limit=60,
                                      find_solution=False,
                                      image_width=320,
                                      image_height=240,  
                                      skip_animation=False,
                                      recording=True,
                                      save_pose_data=True,
                                      file_name_prefix='relax')

# %% [markdown]
# This saves the frames of the video into the `Output/relax` folder, which should be where you had your executable. Let's generate a video from the frames.

# %%
# Enter here the path to the video, it should be in the same location where you stored your executable 
path_video = "./Output/"
utils_viz.generate_video(input_path=path_video, prefix='relax', output_path='.')

# %%
display_vid('./video_normal.mp4')

# %% [markdown]
# Other paramters to render_script are:
# - script: a list of script lines
# - randomize_execution: randomly choose elements
# - random_seed: random seed to use when randomizing execution, -1 means that the seed is not set
# - find_solution: find solution (True) or use graph ids to determine object instances (False)
# - processing_time_limit: time limit for finding a solution
# - skip_execution: skip rendering, only check if a solution exists
# - output_folder: folder to output renderings, default is Output/
# - file_name_prefix: prefix of created files (screenshots are put to output_folder/file_name_prefix/)
# - frame_rate: frame rate
# - capture_screenshot: save screenshots
# - image_synthesis: save depth, segmentation, flow images
# - save_pose_data: save pose data
# - save_scene_states: save scene states
# - character_resource: path to character resource to be used
# - camera_mode: automatic (AUTO), first person (FIRST_PERSON), top (PERSON_TOP), front person view (PERSON_FRONT)

# %%
# We can also visualize the skeleton

path_video = "./Output/"
pose_char, frames = utils_viz.get_skeleton(input_path=path_video, prefix='relax')
ax = plt.axes(projection='3d')
frame = 40
center_char = pose_char.mean(1)
ax.scatter3D(pose_char[frame, :, 0], pose_char[frame, :, 2], pose_char[frame, :, 1])
ax.set_xlim(center_char[frame, 0]-0.8, center_char[frame, 0] + 0.8)
ax.set_ylim(center_char[frame, 2]-0.8, center_char[frame, 2] + 0.8)

# %% [markdown]
# ## Generating a script without a video

# %% [markdown]
# In some occasions you may not be interested in generating a full video for the script, for example if you want to do RL. You can run the script withtout rendering a video by setting image_synthesis to empty. This will execute the script much more quickly

# %% [markdown]
# Restart the previous graph

# %%
comm.reset(4)
comm.expand_scene(prev_graph)
comm.add_character()
s, g = comm.environment_graph()

# %% [markdown]
# Run with `image_synthesis=[]`

# %%
success, message = comm.render_script(script=script,
                                      processing_time_limit=60,
                                      find_solution=False,
                                      image_synthesis=[])

# %% [markdown]
# ## Generating from multiple views

# %% [markdown]
# We can chose which camera to use while rendering the videos. This is done through the flag `CAMERA_MODE`.

# %%
comm.reset(4)
_, _ = comm.expand_scene(last_graph)
comm.add_character()
success, message = comm.render_script(script=script,
                                      processing_time_limit=60,
                                      find_solution=False,
                                      recording=True,
                                      image_synthesis=['normal'],
                                      file_name_prefix='multiview',
                                      camera_mode=['FIRST_PERSON', 'PERSON_TOP'])

# %% [markdown]
# You can specify camera names, for cameras that will follow the character or camera indices, for static cameras. To get the list of camera names, call character_cameras:

# %%
comm.character_cameras()[1]

# %% [markdown]
# ## Generating underspecified videos

# %% [markdown]
# If we do not care which objects the simulator should interact with, we can also let it decide. If we use the flag `find_solution=True` we can start enumerating objects by `1` instead of following the graph ids. Unity will try to find a solution. Note that if we want to interact with 2 objects of the same kind, they will need to have different ids (i.e. 1 and 2)

# %%
comm.reset(0)

# %%
s, g = comm.environment_graph()
[node for node in g['nodes'] if node['class_name'] == 'salmon']

# %%
comm.add_character()

# %%
script = ['<char0> [walk] <salmon> (1)',
          '<char0> [grab] <salmon> (1)',
          '<char0> [walk] <microwave> (1)',
          '<char0> [open] <microwave> (1)',
          '<char0> [putin] <salmon> (1) <microwave> (1)',
          '<char0> [close] <microwave> (1)',
          '<char0> [switchon] <microwave> (1)']
          
success, message = comm.render_script(script=script, 
                                      find_solution=True,
                                      processing_time_limit=80,
                                      frame_rate=15,
                                      image_width=512, image_height=320,
                                      skip_animation=False,
                                      image_synthesis=['normal'],
                                      camera_mode=['PERSON_FROM_BACK'],
                                      recording=True,
                                      file_name_prefix='milk')

# %% [markdown]
# # Multi-agent Actions

# %% [markdown]
# You can also generate actions with multiple agents in them, simply add more agents, and specify which agents should do which action

# %%
# Reset the scene
comm.reset(0)
s, g = comm.environment_graph()
# Add two agents this time
comm.add_character('Chars/Male2', initial_room='kitchen')
comm.add_character('Chars/Female4', initial_room='bedroom')

# Get nodes for salmon and microwave, glass, faucet and sink
salmon_id = [node['id'] for node in g['nodes'] if node['class_name'] == 'salmon'][0]
microwave_id = [node['id'] for node in g['nodes'] if node['class_name'] == 'microwave'][0]
glass_id = [node['id'] for node in g['nodes'] if node['class_name'] == 'waterglass'][-1]
sink_id = [node['id'] for node in g['nodes'] if node['class_name'] == 'sink'][0]
faucet_id = [node['id'] for node in g['nodes'] if node['class_name'] == 'faucet'][-1]


# Put salmon in microwave
script = [
    '<char0> [walk] <salmon> ({}) | <char1> [walk] <glass> ({})'.format(salmon_id, glass_id),
    '<char0> [grab] <salmon> ({}) | <char1> [grab] <glass> ({})'.format(salmon_id, glass_id),
    '<char0> [open] <microwave> ({}) | <char1> [walk] <sink> ({})'.format(microwave_id, sink_id),
    '<char0> [putin] <salmon> ({}) <microwave> ({}) | <char1> [putback] <glass> ({}) <sink> ({})'.format(salmon_id, microwave_id, glass_id, sink_id),
    '<char0> [close] <microwave> ({}) | <char1> [switchon] <faucet> ({})'.format(microwave_id, faucet_id)
]
comm.render_script(script, frame_rate=10, camera_mode=["PERSON_FROM_BACK"], recording=True)

# %% [markdown]
# # Interactive agents

# %% [markdown]
# So far we have seen how to generate videos, but we can use the same command to deploy or train agents in the environment. You can execute the previous instructions one by one, and get an observation or graph at every step. or that, you don't need to generate videos or have animations, since it will slow down your agents. Use `skip_animation=True` to generate actions without animating them. Remember to turn off the recording mode as well.

# %%
# Reset the scene
comm.reset(0)

# Add two agents this time
comm.add_character('Chars/Male2', initial_room='kitchen')
comm.add_character('Chars/Female4', initial_room='bedroom')

# Get nodes for salmon and microwave, glass, faucet and sink
salmon_id = [node['id'] for node in g['nodes'] if node['class_name'] == 'salmon'][0]
microwave_id = [node['id'] for node in g['nodes'] if node['class_name'] == 'microwave'][0]
glass_id = [node['id'] for node in g['nodes'] if node['class_name'] == 'waterglass'][-1]
sink_id = [node['id'] for node in g['nodes'] if node['class_name'] == 'sink'][0]
faucet_id = [node['id'] for node in g['nodes'] if node['class_name'] == 'faucet'][-1]


# Put salmon in microwave
script = [
    '<char0> [walk] <salmon> ({}) | <char1> [walk] <glass> ({})'.format(salmon_id, glass_id),
    '<char0> [grab] <salmon> ({}) | <char1> [grab] <glass> ({})'.format(salmon_id, glass_id),
    '<char0> [open] <microwave> ({}) | <char1> [walk] <sink> ({})'.format(microwave_id, sink_id),
    '<char0> [putin] <salmon> ({}) <microwave> ({}) | <char1> [putback] <glass> ({}) <sink> ({})'.format(salmon_id, microwave_id, glass_id, sink_id),
    '<char0> [close] <microwave> ({}) | <char1> [switchon] <faucet> ({})'.format(microwave_id, faucet_id)
]

s, cc = comm.camera_count()
images = []
for script_instruction in script:
    print(script_instruction)
    comm.render_script([script_instruction], recording=False, skip_animation=True)
    # Here you can get an observation, for instance
    s, im = comm.camera_image([cc-8], image_width=300, image_height=300)
    images.append(im[0])
    
display_grid_img(images, nrows=1)

# %% [markdown]
# # Finer control

# %% [markdown]
# We can also have finer control where objects go via action modifiers, the demo below shows how to place an object in different parts of the table

# %%
comm.reset(0)
s, g = comm.environment_graph()
# Remove stuff from the table and add the character
table = [node for node in g['nodes'] if node['class_name'] == 'kitchentable'][0]
mouse = [node for node in g['nodes'] if node['class_name'] == 'mouse'][0]
mouse_id = mouse['id']
table_id = table['id']

objects_on_table = [edge['from_id'] for edge in g['edges'] 
                    if edge['to_id'] == table['id'] and edge['relation_type'] == 'ON']
new_graph = {
    'nodes': [node for node in g['nodes'] if node['id'] not in objects_on_table],
    'edges': [edge for edge in g['edges'] if edge['from_id'] not in objects_on_table and 
                                             edge['to_id'] not in objects_on_table]
}

comm.expand_scene(new_graph)
comm.add_character()

# This is to get a camera view on top of the character
cc = comm.camera_count()[1] - 7


# Start grabbing the mouse and go to the table
script1 = [f'<char0> [grab] <mouse> ({mouse_id})', 
           f'<char0> [walk] <kitchentable> ({table_id})']
s, m = comm.render_script(script1, skip_animation=True)

images = []

# Place the mouse in some position
posx, posy = -1.1, -5.5
script2 = [f'<char0> [putback] <mouse> ({mouse_id}) <kitchentable> ({table_id}) <position> {posx},{posy}']
s, m = comm.render_script(script2, skip_animation=True)
s, im1 = comm.camera_image([cc])
images.append(im1[0])

# Try a different positiom
posx, posy = -1.3, -5.1
script2 = [f'<char0> [grab] <mouse> ({mouse_id})',
           f'<char0> [putback] <mouse> ({mouse_id}) <kitchentable> ({table_id}) <position> {posx},{posy}']
s, m = comm.render_script(script2, skip_animation=True)
s, im1 = comm.camera_image([cc])
images.append(im1[0])

display_grid_img(images, nrows=1)

# %% [markdown]
# # Physics

# %% [markdown]
# VirtualHome is also able to simulate physics in the environments, and you can use the following api call to alter the gravitational force experienced in the environemnt. By activating physics, all objects behave as expected, just like in the real world. However you can also alter the "g-force" to make the agent feel like they are a astronaut in space.

# %%
# Reset the scene and get the graph
comm.reset(0)
s, g = comm.environment_graph()

# Add a agent 
comm.add_character('Chars/female2', initial_room='kitchen')

# Get nodes for apple, desk, kitchen
apple = [node['id'] for node in g['nodes'] if node['class_name'] == 'apple'][0]
desk = [node['id'] for node in g['nodes'] if node['class_name'] == 'desk'][1]
kitchen = [node['id'] for node in g['nodes'] if node['class_name'] == 'kitchen'][0]

# %%
# Activate gravity
comm.activate_physics()

# %%
# Put apple on desk
script = [
          '<char0> [grab] <apple> ({})'.format(apple),
          '<char0> [put] <apple> ({}) <desk> ({})'.format(apple, desk),
          '<char0> [walk] <kitchen> ({})'.format(kitchen),
          '<char0> [grab] <apple> ({})'.format(apple),
          '<char0> [put] <apple> ({}) <desk> ({}  <position> 0,-3)'.format(apple, desk),
         ]
success, message = comm.render_script(script=script[:2], 
                                      find_solution=True,
                                      processing_time_limit=80,
                                      frame_rate=15,
                                      image_width=512, image_height=320,
                                      skip_animation=False,
                                      image_synthesis=['normal'],
                                      camera_mode=['58'],
                                      recording=True,
                                      file_name_prefix='gravity')

# %%
path_video = "./Output/"
utils_viz.generate_video(input_path=path_video, prefix='gravity', output_path='.')
